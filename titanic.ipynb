# %%
import pandas as pd

# %%
titanic = pd.read_csv("D:/Downloads/archive (2)/Titanic-Dataset.csv")
original = titanic

# %%
y = titanic['Survived']
x = titanic.drop("Survived", axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
original_x_train = x_train

# %%
print(x_train.shape, y_train.shape)
# Out:
# (712, 11) (712,)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 331 to 102
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Pclass       712 non-null    int64
#  2   Name         712 non-null    object
#  3   Sex          712 non-null    object
#  4   Age          572 non-null    float64
#  5   SibSp        712 non-null    int64
#  6   Parch        712 non-null    int64
#  7   Ticket       712 non-null    object
#  8   Fare         712 non-null    float64
#  9   Cabin        159 non-null    object
#  10  Embarked     710 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 66.8+ KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 179 entries, 709 to 10
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  179 non-null    int64
#  1   Pclass       179 non-null    int64
#  2   Name         179 non-null    object
#  3   Sex          179 non-null    object
#  4   Age          142 non-null    float64
#  5   SibSp        179 non-null    int64
#  6   Parch        179 non-null    int64
#  7   Ticket       179 non-null    object
#  8   Fare         179 non-null    float64
#  9   Cabin        45 non-null     object
#  10  Embarked     179 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 16.8+ KB

# %%
y_train.shape
# Out:
# (712,)

# %%
y_test.shape
# Out:
# (179,)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(x_train.shape, y_train.shape)
# Out:
# (712, 11) (712,)

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
x_train
# Out:
#      PassengerId  Pclass                                Name     Sex   Age  \
# 331          332       1                 Partner, Mr. Austen    male  45.5
# 733          734       2          Berriman, Mr. William John    male  23.0
# 382          383       3                  Tikkanen, Mr. Juho    male  32.0
# 704          705       3             Hansen, Mr. Henrik Juul    male  26.0
# 813          814       3  Andersson, Miss. Ebba Iris Alfrida  female   6.0
# ..           ...     ...                                 ...     ...   ...
# 106          107       3    Salkjelsvik, Miss. Anna Kristine  female  21.0
# 270          271       1               Cairns, Mr. Alexander    male   NaN
# 860          861       3             Hansen, Mr. Claus Peter    male  41.0
# 435          436       1           Carter, Miss. Lucile Polk  female  14.0
# 102          103       1           White, Mr. Richard Frasar    male  21.0
#
#      SibSp  Parch             Ticket      Fare    Cabin Embarked
# ...

# %%
x_train = x_train.drop("PassengerId", axis=1)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (712, 10) (712,)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 331 to 102
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    712 non-null    int64
#  1   Name      712 non-null    object
#  2   Sex       712 non-null    object
#  3   Age       572 non-null    float64
#  4   SibSp     712 non-null    int64
#  5   Parch     712 non-null    int64
#  6   Ticket    712 non-null    object
#  7   Fare      712 non-null    float64
#  8   Cabin     159 non-null    object
#  9   Embarked  710 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 61.2+ KB

# %%
age_mode = x_train["Age"].mode()[0]
age_mode
# Out:
# 24.0

# %%
x_train["Age"] = x_train["Age"].fillna(age_mode)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (712, 10) (712,)

# %%
x_train['Age'].isna().sum()
# Out:
# 0

# %%
x_train
# Out:
#      Pclass                                Name     Sex   Age  SibSp  Parch  \
# 331       1                 Partner, Mr. Austen    male  45.5      0      0
# 733       2          Berriman, Mr. William John    male  23.0      0      0
# 382       3                  Tikkanen, Mr. Juho    male  32.0      0      0
# 704       3             Hansen, Mr. Henrik Juul    male  26.0      1      0
# 813       3  Andersson, Miss. Ebba Iris Alfrida  female   6.0      4      2
# ..      ...                                 ...     ...   ...    ...    ...
# 106       3    Salkjelsvik, Miss. Anna Kristine  female  21.0      0      0
# 270       1               Cairns, Mr. Alexander    male  24.0      0      0
# 860       3             Hansen, Mr. Claus Peter    male  41.0      2      0
# 435       1           Carter, Miss. Lucile Polk  female  14.0      1      2
# 102       1           White, Mr. Richard Frasar    male  21.0      0      1
#
#                 Ticket      Fare    Cabin Embarked
# ...

# %%
x_train.isnull().sum()
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       553
# Embarked      2
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

x_train['Sex'] = encoder.fit_transform(x_train['Sex'])

# %%
print(x_train.shape, y_train.shape)
# Out:
# (712, 10) (712,)

# %%
x_train
# Out:
#      Pclass                                Name  Sex   Age  SibSp  Parch  \
# 331       1                 Partner, Mr. Austen    1  45.5      0      0
# 733       2          Berriman, Mr. William John    1  23.0      0      0
# 382       3                  Tikkanen, Mr. Juho    1  32.0      0      0
# 704       3             Hansen, Mr. Henrik Juul    1  26.0      1      0
# 813       3  Andersson, Miss. Ebba Iris Alfrida    0   6.0      4      2
# ..      ...                                 ...  ...   ...    ...    ...
# 106       3    Salkjelsvik, Miss. Anna Kristine    0  21.0      0      0
# 270       1               Cairns, Mr. Alexander    1  24.0      0      0
# 860       3             Hansen, Mr. Claus Peter    1  41.0      2      0
# 435       1           Carter, Miss. Lucile Polk    0  14.0      1      2
# 102       1           White, Mr. Richard Frasar    1  21.0      0      1
#
#                 Ticket      Fare    Cabin Embarked
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

x_train['Embarked'] = x_train['Embarked'].fillna('Missing')

encoder = OneHotEncoder(sparse_output=False)
encoded = encoder.fit_transform(x_train[['Embarked']])
encoded_df = pd.DataFrame(encoded, columns=encoder.get_feature_names_out(['Embarked']), index=x_train.index)

x_train_final = pd.concat([x_train, encoded_df], axis=1)

x_train_final = x_train_final.drop('Embarked', axis=1)

for col in ['Name', 'Ticket', 'Cabin']:
    if col in x_train_final.columns:
        x_train_final = x_train_final.drop(col, axis=1)

print("Final shape:", x_train_final.shape)
print(x_train_final.head())
# Out:
# Final shape: (712, 10)
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Missing  \
# 331       1    1  45.5      0      0  28.5000         0.0               0.0
# 733       2    1  23.0      0      0  13.0000         0.0               0.0
# 382       3    1  32.0      0      0   7.9250         0.0               0.0
# 704       3    1  26.0      1      0   7.8542         0.0               0.0
# 813       3    0   6.0      4      2  31.2750         0.0               0.0
#
#      Embarked_Q  Embarked_S
# 331         0.0         1.0
# 733         0.0         1.0
# 382         0.0         1.0
# 704         0.0         1.0
# 813         0.0         1.0

# %%
x_train = x_train_final

# %%
print(x_train.shape, y_train.shape)
# Out:
# (712, 10) (712,)

# %%
x_train
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked_C  Embarked_Missing  \
# 331       1    1  45.5      0      0   28.5000         0.0               0.0
# 733       2    1  23.0      0      0   13.0000         0.0               0.0
# 382       3    1  32.0      0      0    7.9250         0.0               0.0
# 704       3    1  26.0      1      0    7.8542         0.0               0.0
# 813       3    0   6.0      4      2   31.2750         0.0               0.0
# ..      ...  ...   ...    ...    ...       ...         ...               ...
# 106       3    0  21.0      0      0    7.6500         0.0               0.0
# 270       1    1  24.0      0      0   31.0000         0.0               0.0
# 860       3    1  41.0      2      0   14.1083         0.0               0.0
# 435       1    0  14.0      1      2  120.0000         0.0               0.0
# 102       1    1  21.0      0      1   77.2875         0.0               0.0
#
#      Embarked_Q  Embarked_S
# ...

# %%
x_train = x_train.drop('Embarked_Missing', axis=1)

# %%
x_train
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked_C  Embarked_Q  \
# 331       1    1  45.5      0      0   28.5000         0.0         0.0
# 733       2    1  23.0      0      0   13.0000         0.0         0.0
# 382       3    1  32.0      0      0    7.9250         0.0         0.0
# 704       3    1  26.0      1      0    7.8542         0.0         0.0
# 813       3    0   6.0      4      2   31.2750         0.0         0.0
# ..      ...  ...   ...    ...    ...       ...         ...         ...
# 106       3    0  21.0      0      0    7.6500         0.0         0.0
# 270       1    1  24.0      0      0   31.0000         0.0         0.0
# 860       3    1  41.0      2      0   14.1083         0.0         0.0
# 435       1    0  14.0      1      2  120.0000         0.0         0.0
# 102       1    1  21.0      0      1   77.2875         0.0         0.0
#
#      Embarked_S
# 331         1.0
# 733         1.0
# 382         1.0
# 704         1.0
# 813         1.0
# ...

# %%
print(x_train.shape, y_train.shape)
# Out:
# (712, 9) (712,)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 331 to 102
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Pclass      712 non-null    int64
#  1   Sex         712 non-null    int32
#  2   Age         712 non-null    float64
#  3   SibSp       712 non-null    int64
#  4   Parch       712 non-null    int64
#  5   Fare        712 non-null    float64
#  6   Embarked_C  712 non-null    float64
#  7   Embarked_Q  712 non-null    float64
#  8   Embarked_S  712 non-null    float64
# dtypes: float64(5), int32(1), int64(3)
# memory usage: 52.8 KB

# %%
x_train['SibSp'].value_counts()
# Out:
# SibSp
# 0    484
# 1    164
# 2     23
# 4     16
# 3     13
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
x_train['Parch'].value_counts()
# Out:
# Parch
# 0    541
# 1     94
# 2     67
# 4      3
# 3      3
# 5      3
# 6      1
# Name: count, dtype: int64

# %%
x_train['FamilySize'] = x_train['SibSp'] + x_train['Parch']

# %%
x_train['FamilySize'].value_counts()
# Out:
# FamilySize
# 0     429
# 1     127
# 2      79
# 3      26
# 5      17
# 4      11
# 6      10
# 10      7
# 7       6
# Name: count, dtype: int64

# %%
x_train.loc[x_train["FamilySize"] > 0, "FamilySize"] = 1

# %%
x_train['FamilySize'].value_counts()
# Out:
# FamilySize
# 0    429
# 1    283
# Name: count, dtype: int64

# %%
x_train.rename(columns={"FamilySize": "has_Family"}, inplace=True)

# %%
x_train
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked_C  Embarked_Q  \
# 331       1    1  45.5      0      0   28.5000         0.0         0.0
# 733       2    1  23.0      0      0   13.0000         0.0         0.0
# 382       3    1  32.0      0      0    7.9250         0.0         0.0
# 704       3    1  26.0      1      0    7.8542         0.0         0.0
# 813       3    0   6.0      4      2   31.2750         0.0         0.0
# ..      ...  ...   ...    ...    ...       ...         ...         ...
# 106       3    0  21.0      0      0    7.6500         0.0         0.0
# 270       1    1  24.0      0      0   31.0000         0.0         0.0
# 860       3    1  41.0      2      0   14.1083         0.0         0.0
# 435       1    0  14.0      1      2  120.0000         0.0         0.0
# 102       1    1  21.0      0      1   77.2875         0.0         0.0
#
#      Embarked_S  has_Family
# 331         1.0           0
# 733         1.0           0
# ...

# %%
x_train = x_train.drop('SibSp',axis=1)
x_train = x_train.drop('Parch',axis=1)

# %%
x_train
# Out:
#      Pclass  Sex   Age      Fare  Embarked_C  Embarked_Q  Embarked_S  \
# 331       1    1  45.5   28.5000         0.0         0.0         1.0
# 733       2    1  23.0   13.0000         0.0         0.0         1.0
# 382       3    1  32.0    7.9250         0.0         0.0         1.0
# 704       3    1  26.0    7.8542         0.0         0.0         1.0
# 813       3    0   6.0   31.2750         0.0         0.0         1.0
# ..      ...  ...   ...       ...         ...         ...         ...
# 106       3    0  21.0    7.6500         0.0         0.0         1.0
# 270       1    1  24.0   31.0000         0.0         0.0         1.0
# 860       3    1  41.0   14.1083         0.0         0.0         1.0
# 435       1    0  14.0  120.0000         0.0         0.0         1.0
# 102       1    1  21.0   77.2875         0.0         0.0         1.0
#
#      has_Family
# 331           0
# 733           0
# 382           0
# 704           1
# 813           1
# ..          ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Sex', hue='Survived', data=original)
plt.title("Survival Counts by Gender")
plt.show()

# %%
survived = original[original['Survived'] == 1]

sns.countplot(x='Sex', hue='Sex' , data=survived)
plt.title("Survived Passengers by Gender")
plt.show()

# %%
survived = original[original['Survived'] == 1]

sns.countplot(x='Pclass', hue='Pclass' , data=survived)
plt.title("Survived Passengers by Pclass")
plt.show()

# %%
x_train
# Out:
#      Pclass  Sex   Age      Fare  Embarked_C  Embarked_Q  Embarked_S  \
# 331       1    1  45.5   28.5000         0.0         0.0         1.0
# 733       2    1  23.0   13.0000         0.0         0.0         1.0
# 382       3    1  32.0    7.9250         0.0         0.0         1.0
# 704       3    1  26.0    7.8542         0.0         0.0         1.0
# 813       3    0   6.0   31.2750         0.0         0.0         1.0
# ..      ...  ...   ...       ...         ...         ...         ...
# 106       3    0  21.0    7.6500         0.0         0.0         1.0
# 270       1    1  24.0   31.0000         0.0         0.0         1.0
# 860       3    1  41.0   14.1083         0.0         0.0         1.0
# 435       1    0  14.0  120.0000         0.0         0.0         1.0
# 102       1    1  21.0   77.2875         0.0         0.0         1.0
#
#      has_Family
# 331           0
# 733           0
# 382           0
# 704           1
# 813           1
# ..          ...
# ...

# %%
train_data = x_train.copy()
train_data['Survived'] = y_train.values
survived = train_data[train_data['Survived'] == 1]

sns.countplot(x='has_Family', hue='has_Family', data=survived)
plt.title("Survival by Family Presence")
plt.show()

# %%
x_train['Age'].describe()
# Out:
# count    712.000000
# mean      28.417612
# std       13.177068
# min        0.420000
# 25%       22.000000
# 50%       24.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.histplot(titanic['Age'].dropna(), bins=20, color="skyblue")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
sns.kdeplot(titanic['Age'].dropna(), fill=True, color="orange")
plt.title("Age Density Plot")
plt.xlabel("Age")
plt.show()

# %%
train_data = x_train.copy()
train_data['Survived'] = y_train.values
sns.violinplot(x="Survived", y="Age", data=train_data)
plt.title("Age Distribution by Survival (Violin Plot)")
plt.show()

# %%
train_data = x_train.copy()
train_data['Survived'] = y_train.values
sns.histplot(data=train_data, x='Age', hue='Survived', bins=20,multiple="dodge",shrink=0.8)
plt.title("Age Distribution by Survival")
plt.show()

# %%
train_data = x_train.copy()
train_data['Survived'] = y_train.values
correlations = train_data.corr()['Survived'].drop('Survived')
print(correlations.abs().sort_values(ascending=False))
# Out:
# Sex           0.541750
# Pclass        0.321750
# Fare          0.246641
# has_Family    0.180542
# Embarked_C    0.159632
# Embarked_S    0.142371
# Age           0.033261
# Embarked_Q    0.006097
# Name: Survived, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(train_data.corr().abs(), annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap", fontsize=14)
plt.show()

# %%
embarked_cols = ['Embarked_C', 'Embarked_S', 'Embarked_Q']
counts = train_data[embarked_cols].sum()
sns.barplot(x=counts.index, y=counts.values, palette='Set2')
plt.xlabel('Embarked')
plt.ylabel('Count')
plt.title('Count of Passengers by Embarked Category')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15996\1056982307.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, palette='Set2')

# %%
embarked_cols = ['Embarked_C', 'Embarked_S', 'Embarked_Q']
survived_counts = {}
for col in embarked_cols:
    survived_counts[col] = train_data[train_data[col] == 1]['Survived'].sum()
sns.barplot(x=list(survived_counts.keys()), y=list(survived_counts.values()), palette='Set1')
plt.xlabel('Embarked')
plt.ylabel('Number of Survivors')
plt.title('Survivors from Each Embarked Category')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15996\954953487.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(survived_counts.keys()), y=list(survived_counts.values()), palette='Set1')

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(x_train,y_train)
# Out:
# SGDClassifier(random_state=42)

# %%
y_pred_sgd= sgd_clf.predict(x_train)

# %%
y_pred_sgd[:5]
# Out:
# array([0, 0, 0, 0, 0], dtype=int64)

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(sgd_clf,x_train,y_train,cv=3,scoring="accuracy")
# Out:
# array([0.37815126, 0.6371308 , 0.69620253])

# %%
from sklearn.dummy import DummyClassifier

dummy_clf = DummyClassifier(strategy='stratified')
dummy_clf.fit(x_train, y_train)
y_pred_dummy = dummy_clf.predict(x_train)

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(dummy_clf,x_train,y_train,cv=3,scoring="accuracy")
# Out:
# array([0.50420168, 0.55696203, 0.5021097 ])

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(max_iter=500)
log_reg.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
log_pred = log_reg.predict(x_train)

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(log_reg,x_train,y_train,cv=3,scoring="accuracy")
# Out:
# array([0.78151261, 0.79324895, 0.79324895])

# %%
from sklearn.svm import SVC 

svm_classifier = SVC(kernel='linear',C=1)
svm_classifier.fit(x_train,y_train)
svm_pred = svm_classifier.predict(x_train)

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(svm_classifier,x_train,y_train,cv=3,scoring="accuracy")
# Out:
# array([0.77731092, 0.78481013, 0.80168776])

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(criterion='gini',random_state=42,max_depth=3,min_samples_leaf=5)
tree.fit(x_train,y_train)
tree_pred = tree.predict(x_train)

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(tree,x_train,y_train,cv=3,scoring="accuracy")
# Out:
# array([0.80252101, 0.83122363, 0.8185654 ])

# %%
from sklearn.ensemble import RandomForestClassifier

random_class = RandomForestClassifier(n_estimators=100, random_state=42)
random_class.fit(x_train,y_train)
random_pred = random_class.predict(x_train)

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(random_class,x_train,y_train,cv=3,scoring="accuracy")
# Out:
# array([0.77731092, 0.78902954, 0.79324895])

# %%
from sklearn.metrics import confusion_matrix
cm_sgd = confusion_matrix(y_train,y_pred_sgd)
cm_sgd
# Out:
# array([[444,   0],
#        [263,   5]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
cm_dummy = confusion_matrix(y_train,y_pred_dummy)
cm_dummy
# Out:
# array([[291, 153],
#        [164, 104]], dtype=int64)

# %%
cm_log = confusion_matrix(y_train,log_pred)
cm_log
# Out:
# array([[377,  67],
#        [ 80, 188]], dtype=int64)

# %%
cm_svm = confusion_matrix(y_train,svm_pred)
cm_svm
# Out:
# array([[380,  64],
#        [ 87, 181]], dtype=int64)

# %%
cm_tree = confusion_matrix(y_train,tree_pred)
cm_tree
# Out:
# array([[400,  44],
#        [ 79, 189]], dtype=int64)

# %%
cm_random = confusion_matrix(y_train,random_pred)
cm_random
# here we clearly see that random forest is better
# Out:
# array([[440,   4],
#        [ 11, 257]], dtype=int64)

# %%
from sklearn.metrics import precision_score,recall_score
precision_score(y_train,random_pred)
# Out:
# 0.9846743295019157

# %%
recall_score(y_train,random_pred)
# Out:
# 0.9589552238805971

# %%
from sklearn.metrics import f1_score
f1_score(y_train,random_pred)
# Out:
# 0.9716446124763705

# %%
from sklearn.metrics import precision_recall_curve

precision , recall , threshold = precision_recall_curve(y_train,random_pred)

# %%
plt.plot(threshold, precision[:-1], "b--", label="Precision", linewidth=2)
plt.plot(threshold, recall[:-1], "g-", label="Recall", linewidth=2)
plt.xlabel("Threshold")
plt.ylabel("Score")
plt.legend()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve

precision , recall , threshold = precision_recall_curve(y_train,tree_pred)

# %%
plt.plot(threshold, precision[:-1], "b--", label="Precision", linewidth=2)
plt.plot(threshold, recall[:-1], "g-", label="Recall", linewidth=2)
plt.xlabel("Threshold")
plt.ylabel("Score")
plt.legend()
plt.show()

# %%
plt.plot(recall,precision,linewidth= 2 , label = "precisioon/recall curve")
thr = 0.7
closest_idx = (abs(threshold-thr)).argmin()
plt.scatter(recall[closest_idx],precision[closest_idx],color = "Black",s=80)
plt.axvline(x=recall[closest_idx], color="Black", linestyle="--", alpha=0.7)
plt.axhline(y=precision[closest_idx], color="Black", linestyle="--", alpha=0.7)
plt.show()

# %%
from sklearn.metrics import roc_curve

fpr,tpr,threshold = roc_curve(y_train,random_pred)

# %%
idx_for_90_precision = (precision >= 0.80).argmax()
threshold_for_90_precision = threshold[idx_for_90_precision]
threshold_for_90_precision
# Out:
# 1.0

# %%
plt.plot(fpr,tpr,linewidth = 2 , label = "ROC curve")
plt.plot([0,1],[0,1],'k:',label="Random Classifier's ROC curve")
plt.grid(True)
plt.legend(loc = "lower right")
plt.ylabel("True Positive Rate (Recall)")
plt.xlabel("False Positive Rate (Fall-out)")
plt.show()

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_train,random_pred)
# Out:
# 0.974973107435794

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_predict

random_pred = cross_val_predict(random_class,x_train,y_train,cv=3)
ConfusionMatrixDisplay.from_predictions(y_train,random_pred)
plt.show()

# %%
ConfusionMatrixDisplay.from_predictions(y_train,random_pred,normalize="true",values_format=".0%")
plt.show()

# %%
x_test
# Out:
#      PassengerId  Pclass                                               Name  \
# 709          710       3  Moubarek, Master. Halim Gonios ("William George")
# 439          440       2             Kvillner, Mr. Johan Henrik Johannesson
# 840          841       3                        Alhomaki, Mr. Ilmari Rudolf
# 720          721       2                  Harper, Miss. Annie Jessie "Nina"
# 39            40       3                        Nicola-Yarred, Miss. Jamila
# ..           ...     ...                                                ...
# 433          434       3                         Kallio, Mr. Nikolai Erland
# 773          774       3                                    Elias, Mr. Dibo
# 25            26       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 84            85       2                                Ilett, Miss. Bertha
# 10            11       3                    Sandstrom, Miss. Marguerite Rut
#
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, FunctionTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.tree import DecisionTreeClassifier

class HasFamilyTransformer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X = X.copy()
        X['HasFamily'] = ((X['SibSp'] + X['Parch']) > 0).astype(int)
        X = X.drop(['SibSp', 'Parch'], axis=1)
        return X
class DropColumnsTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, columns_to_drop):
        self.columns_to_drop = columns_to_drop
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        return X.drop(self.columns_to_drop, axis=1)
numeric_features = ['Age', 'Fare']
categorical_features = ['Sex', 'Embarked']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')) 
])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')), 
    ('onehot', OneHotEncoder(handle_unknown='ignore'))  
])
preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, numeric_features),
    ('cat', categorical_transformer, categorical_features)
])

# %%
model = Pipeline(steps=[
    ('drop_id', DropColumnsTransformer(columns_to_drop=['PassengerId'])),
    ('has_family', HasFamilyTransformer()),
    ('drop_other', DropColumnsTransformer(columns_to_drop=['Name', 'Ticket', 'Cabin'])),
    ('preprocessor', preprocessor),
    ('classifier', DecisionTreeClassifier(criterion='entropy',max_depth=5,min_samples_split=2,min_samples_leaf=1))
])

# %%
model.fit(original_x_train, y_train)
# Out:
# Pipeline(steps=[('drop_id',
#                  DropColumnsTransformer(columns_to_drop=['PassengerId'])),
#                 ('has_family', HasFamilyTransformer()),
#                 ('drop_other',
#                  DropColumnsTransformer(columns_to_drop=['Name', 'Ticket',
#                                                          'Cabin'])),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent'))]),
#                                                   ['Age', 'Fare']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
# ...

# %%
y_pred_final = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("Test Accuracy:", accuracy_score(y_test, y_pred_final))
# Out:
# Test Accuracy: 0.776536312849162

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plot_tree(model.named_steps['classifier'], feature_names=x_train.columns, filled=True)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

param_grid = {
    'classifier__max_depth': [3, 5, 7, 10],
    'classifier__min_samples_split': [2, 5, 10],
    'classifier__min_samples_leaf': [1, 2, 4],
    'classifier__criterion': ['gini', 'entropy']
}

grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(original_x_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best accuracy:", grid_search.best_score_)
# Out:
# Best parameters: {'classifier__criterion': 'entropy', 'classifier__max_depth': 5, 'classifier__min_samples_leaf': 1, 'classifier__min_samples_split': 2}
# Best accuracy: 0.7963557569191371

# %%
cm_final = confusion_matrix(y_test,y_pred_final)
cm_final
# Out:
# array([[91, 14],
#        [26, 48]], dtype=int64)

# %%
precision_score(y_test,y_pred_final)
# Out:
# 0.7741935483870968

# %%
recall_score(y_test,y_pred_final)
# Out:
# 0.6486486486486487
